# %%
x=2
print(type(x))
# Out:
# <class 'int'>

# %%
x="apple"
print(type(x))
# Out:
# <class 'str'>

# %%
print(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fc0364975534> in <module>()
# ----> 1 print(f)
#
# NameError: name 'f' is not defined

# %%
print(1+2)
print(1*2)
print(1-2)
print(1/2)
# Out:
# 3
# 2
# -1
# 0.5

# %%
print(3.5/2.5)
# Out:
# 1.4

# %%
print(2**15)
# Out:
# 32768

# %%
print(type(1+2))
print(type(1.0+2))
# Out:
# <class 'int'>
# <class 'float'>

# %%
print(True==True)
print(True>False)
print(True<False)
# Out:
# True
# True
# False

# %%
print(not True)
# Out:
# False

# %%
print(False or True)
# Out:
# True

# %%
print(11==12)
# Out:
# False

# %%
name="red "
location="charlotte "
state="SC "
print(name+location+state)
# Out:
# red charlotte SC

# %%
print(len("Hello world!"))
# Out:
# 12

# %%
name="red ventures"
print(name[0])
# Out:
# r

# %%
name="red ventures"
print(name[0:3])
# Out:
# red

# %%
s="Red Ventures"
print(s[4:5])
# Out:
# V

# %%
s = "Charlotte"

print(s[len(s)-1])
# Out:
# e

# %%
print('    Everything is written in pencil.')
# Out:
#     Everything is written in pencil.

# %%
print('Everything is written
 in pencil.')
# Out:
#   File "<ipython-input-39-55b450bd2dcc>", line 1
#     print('Everything is written
#                                 ^
# SyntaxError: EOL while scanning string literal

# %%
print('Everything \ is written \ in pencil.')
# Out:
# Everything \ is written \ in pencil.

# %%
print('Red Ventures brands, just list a few:
   * Bankrate
   * Reviews.com
   * the Points Guy
   * creditcards.com')
# Out:
#   File "<ipython-input-40-d21b1f67c59b>", line 1
#     print('Red Ventures brands, just list a few:
#                                                 ^
# SyntaxError: EOL while scanning string literal

# %%
# TODO
s = 'RED FISH'
print(s.lower())
# Out:
# red fish

# %%
s = 'Run Up Escalators'
print(s.startswith("r"))
# Out:
# False

# %%
s = "You don't have to lie."
print(s.find("'"))
# Out:
# 7

# %%
# created a variable z
z=34
print(type(int(z)))
# Out:
# <class 'int'>

# %%
print(type(1+2)==type(1.0+2))
# Out:
# False

# %%
num_int = 123
num_str = "456"
print(num_int+int(num_str))
print(str(num_int+int(num_str)))
##print(type(str(num_int+int(num_str))))
# Out:
# 579
# 579
# <class 'str'>

# %%
print(bool(-1))
# Out:
# True

# %%
import math

# %%
math.exp(4)
# Out:
# 54.598150033144236

# %%
print(math.log(8,2))
# Out:
# 3.0

# %%
print(math.sqrt(100))
# Out:
# 10.0
